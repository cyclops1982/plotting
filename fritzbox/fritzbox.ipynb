# %%
# %matplotlib notebook
# %precision 3

from IPython.display import set_matplotlib_formats
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import matplotlib

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
plt.rcParams['figure.figsize'] = [9, 5]
plt.rcParams['timezone'] = 'Europe/London'

import pandas

from datetime import datetime

# %%
data = pandas.read_html('output/1595110539_dslstats.html')
data[0]
# Out:
#                         Unnamed: 0 Unnamed: 1 Receive Direction Send Direction
# 0            Max. DSLAM throughput     kbit/s             40000           7200
# 1            Min. DSLAM throughput     kbit/s               128              -
# 2            Attainable throughput     kbit/s             74121          17193
# 3               Current throughput     kbit/s             39997           7200
# 4         Seamless rate adaptation        NaN               off            off
# 5                              NaN        NaN               NaN            NaN
# 6                          Latency        NaN              fast           fast
# 7   Impulse Noise Protection (INP)        NaN                44             43
# 8                            G.INP        NaN                on             on
# 9                              NaN        NaN               NaN            NaN
# 10           Signal-to-noise ratio         dB                16             14
# 11                         Bitswap        NaN                on            off
# 12                Line attenuation         dB                18             24
# 13         approximate line length          m               488            NaN
# 14                             NaN        NaN               NaN            NaN
# 15                         Profile        17a               NaN            NaN
# 16                        G.Vector        NaN               off            off
# 17                             NaN        NaN               NaN            NaN
# 18                  Carrier record        NaN               A43            A43
