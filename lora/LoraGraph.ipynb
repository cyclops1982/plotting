# %%
# %matplotlib notebook
# %precision 3
# %config IPCompleter.greedy=True

from IPython.display import set_matplotlib_formats
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import matplotlib

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

plt.rcParams['figure.figsize'] = [9, 4]
plt.rcParams['timezone'] = 'Europe/London'

import pandas

from datetime import datetime

# %%
data=pandas.read_csv("csvdata.csv",skipinitialspace=True)
w

data
# Out:
#                        Unixtime  RawVoltage  boardtemp       Long      Lat  \
# datetime
# 2020-11-01 14:10:30  1604239830         133         29  513868380 -4081418
# 2020-11-01 14:11:33  1604239893         133         25  513868171 -4081365
# 2020-11-01 14:13:07  1604239987         133         24  513868616 -4080872
# 2020-11-01 14:14:35  1604240075         133         23  513870041 -4082352
# 2020-11-01 14:16:10  1604240170         133         22  513868980 -4081168
# ...                         ...         ...        ...        ...      ...
# 2020-11-02 08:06:20  1604304380         132         24  513869163 -4080685
# 2020-11-02 08:07:19  1604304439         132         24  513868982 -4080467
# 2020-11-02 08:08:31  1604304511         132         24  513869841 -4081012
# 2020-11-02 08:09:32  1604304572         132         24  513869849 -4081492
# 2020-11-02 08:10:27  1604304627         132         24  513871846 -4081044
#
#                      Alt  Speed  Course  Satelites  SecondsToFix  hAccuracy  \
# datetime
# 2020-11-01 14:10:30    4      0       0          6           121      11410
# 2020-11-01 14:11:33  -13      2     200          6            26      12544
# 2020-11-01 14:13:07   13      0     203          8            81       9931
# 2020-11-01 14:14:35    3      0     208          8            28      14592
# 2020-11-01 14:16:10    6      0     248          8            63      14793
# ...                  ...    ...     ...        ...           ...        ...
# 2020-11-02 08:06:20   23      0       5          8            13      12943
# 2020-11-02 08:07:19   18      0      48          7            12      12469
# 2020-11-02 08:08:31   30      2       0          8            24      13593
# 2020-11-02 08:09:32   36      0     211          8            25      13357
# 2020-11-02 08:10:27   39      5      15          8            20      14361
#
#                      vAccuracy             DateTime  CalcVoltage   CalcLong  \
# datetime
# 2020-11-01 14:10:30      16151  2020-11-01 14:10:30     3.782353  51.386838
# 2020-11-01 14:11:33      15483  2020-11-01 14:11:33     3.782353  51.386817
# 2020-11-01 14:13:07      14462  2020-11-01 14:13:07     3.782353  51.386862
# 2020-11-01 14:14:35      13615  2020-11-01 14:14:35     3.782353  51.387004
# 2020-11-01 14:16:10      13354  2020-11-01 14:16:10     3.782353  51.386898
# ...                        ...                  ...          ...        ...
# 2020-11-02 08:06:20      15074  2020-11-02 08:06:20     3.776471  51.386916
# 2020-11-02 08:07:19      15178  2020-11-02 08:07:19     3.776471  51.386898
# 2020-11-02 08:08:31      14205  2020-11-02 08:08:31     3.776471  51.386984
# 2020-11-02 08:09:32      14595  2020-11-02 08:09:32     3.776471  51.386985
# 2020-11-02 08:10:27      13482  2020-11-02 08:10:27     3.776471  51.387185
#
#                       CalcLat  Unnamed: 16
# datetime
# 2020-11-01 14:10:30 -0.408142          NaN
# 2020-11-01 14:11:33 -0.408136          NaN
# 2020-11-01 14:13:07 -0.408087          NaN
# 2020-11-01 14:14:35 -0.408235          NaN
# 2020-11-01 14:16:10 -0.408117          NaN
# ...                       ...          ...
# 2020-11-02 08:06:20 -0.408069          NaN
# 2020-11-02 08:07:19 -0.408047          NaN
# 2020-11-02 08:08:31 -0.408101          NaN
# 2020-11-02 08:09:32 -0.408149          NaN
# 2020-11-02 08:10:27 -0.408104          NaN
#
# [1045 rows x 17 columns]

# %%
plt.figure()


plt.plot(data["hAccuracy"], label = "Horizontal Accuracy")
plt.plot(data["vAccuracy"], label = "Vertical Accuracy")
ax = plt.gca()


ax.xaxis.grid(True, which='both')
ax.tick_params(axis='x',which='major', length=35)
ax.tick_params(axis='x',which='minor', rotation=90)

#ax.yaxis.set_major_locator(ticker.IndexLocator(1,0));
#ax.yaxis.set_minor_locator(ticker.AutoLocator());
#ax.yaxis.grid(True, which='major')
#ax.set_ylim([3, 4])
#ax.axhline(0, color='black', lw=1)


ax2 = ax.twinx();
ax2.plot(data["Satelites"], label = "Satelites", linewidth=1, color='blue')
ax2.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
ax2.xaxis.set_major_locator(mdates.DayLocator())
ax2.xaxis.set_minor_formatter(mdates.DateFormatter("%H:%M"))
ax2.xaxis.set_minor_locator(mdates.HourLocator())
ax2.xaxis.grid(True, which='both')

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="900">
