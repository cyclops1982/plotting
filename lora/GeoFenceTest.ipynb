# %%
# %matplotlib notebook
# %precision 3

import pandas as pd
import folium
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import geopandas as gpd

from datetime import datetime
from IPython.display import set_matplotlib_formats
from pandas.plotting import register_matplotlib_converters

register_matplotlib_converters()

plt.rcParams['figure.figsize'] = [9, 7]
plt.rcParams['timezone'] = 'Europe/London'

# %%
data=pd.read_csv("csvdata.csv",skipinitialspace=True)
data["datetime"]=pd.to_datetime(data["Unixtime"], unit='s')
data.set_index("datetime", inplace=True)
data = data.drop("Unnamed: 16", 1)
data
# Out:
#                        Unixtime  RawVoltage  boardtemp        Lat     Long  \
# datetime
# 2020-11-05 18:51:45  1604602305         123         24  513869363 -4083901
# 2020-11-05 18:52:20  1604602340         123         24  513867734 -4083528
# 2020-11-05 18:53:31  1604602411         123         24  513868182 -4082726
# 2020-11-05 18:54:29  1604602469         123         25  513868594 -4081939
# 2020-11-05 18:55:31  1604602531         123         26  513868561 -4082163
# ...                         ...         ...        ...        ...      ...
# 2020-11-06 19:09:41  1604689781          75         23  513869156 -4082764
# 2020-11-06 19:11:09  1604689869          75         23  513869382 -4081007
# 2020-11-06 19:12:29  1604689949          75         23  513869543 -4081180
# 2020-11-06 19:13:33  1604690013          75         23  513869295 -4081326
# 2020-11-06 19:14:25  1604690065          75         23  513868394 -4081350
#
#                      Alt  Speed  Course  Satelites  SecondsToFix  hAccuracy  \
# datetime
# 2020-11-05 18:51:45  -27      3     221          9            38      10891
# 2020-11-05 18:52:20   40      5     212          9            13      12465
# 2020-11-05 18:53:31   -5      2     220         10            24       9678
# 2020-11-05 18:54:29   -7      1     222          9            22       8505
# 2020-11-05 18:55:31  -16      0     208          9            24       8727
# ...                  ...    ...     ...        ...           ...        ...
# 2020-11-06 19:09:41   66      0     226          9            34       8679
# 2020-11-06 19:11:09    6      0      14          8            62       9309
# 2020-11-06 19:12:29   22      0       6          9            22       9915
# 2020-11-06 19:13:33   33      0     231          8            26       9985
# 2020-11-06 19:14:25   36      0      20          8            18      10096
#
#                      vAccuracy             DateTime  CalcVoltage    CalcLat  \
# datetime
# 2020-11-05 18:51:45      22468  2020-11-05 18:51:45     3.723529  51.386936
# 2020-11-05 18:52:20      21032  2020-11-05 18:52:20     3.723529  51.386773
# 2020-11-05 18:53:31      22833  2020-11-05 18:53:31     3.723529  51.386818
# 2020-11-05 18:54:29      23170  2020-11-05 18:54:29     3.723529  51.386859
# 2020-11-05 18:55:31      23045  2020-11-05 18:55:31     3.723529  51.386856
# ...                        ...                  ...          ...        ...
# 2020-11-06 19:09:41      23075  2020-11-06 19:09:41     3.441176  51.386916
# 2020-11-06 19:11:09      23008  2020-11-06 19:11:09     3.441176  51.386938
# 2020-11-06 19:12:29      22700  2020-11-06 19:12:29     3.441176  51.386954
# 2020-11-06 19:13:33      22842  2020-11-06 19:13:33     3.441176  51.386930
# 2020-11-06 19:14:25      22643  2020-11-06 19:14:25     3.441176  51.386839
#
#                      CalcLong
# datetime
# 2020-11-05 18:51:45 -0.408390
# 2020-11-05 18:52:20 -0.408353
# 2020-11-05 18:53:31 -0.408273
# 2020-11-05 18:54:29 -0.408194
# 2020-11-05 18:55:31 -0.408216
# ...                       ...
# 2020-11-06 19:09:41 -0.408276
# 2020-11-06 19:11:09 -0.408101
# 2020-11-06 19:12:29 -0.408118
# 2020-11-06 19:13:33 -0.408133
# 2020-11-06 19:14:25 -0.408135
#
# [1348 rows x 16 columns]

# %%
gdf = gpd.GeoDataFrame( data, geometry=gpd.points_from_xy(data.CalcLong, data.CalcLat))
gdf
# Out:
#                        Unixtime  RawVoltage  boardtemp        Lat     Long  \
# datetime
# 2020-11-05 18:51:45  1604602305         123         24  513869363 -4083901
# 2020-11-05 18:52:20  1604602340         123         24  513867734 -4083528
# 2020-11-05 18:53:31  1604602411         123         24  513868182 -4082726
# 2020-11-05 18:54:29  1604602469         123         25  513868594 -4081939
# 2020-11-05 18:55:31  1604602531         123         26  513868561 -4082163
# ...                         ...         ...        ...        ...      ...
# 2020-11-06 19:09:41  1604689781          75         23  513869156 -4082764
# 2020-11-06 19:11:09  1604689869          75         23  513869382 -4081007
# 2020-11-06 19:12:29  1604689949          75         23  513869543 -4081180
# 2020-11-06 19:13:33  1604690013          75         23  513869295 -4081326
# 2020-11-06 19:14:25  1604690065          75         23  513868394 -4081350
#
#                      Alt  Speed  Course  Satelites  SecondsToFix  hAccuracy  \
# datetime
# 2020-11-05 18:51:45  -27      3     221          9            38      10891
# 2020-11-05 18:52:20   40      5     212          9            13      12465
# 2020-11-05 18:53:31   -5      2     220         10            24       9678
# 2020-11-05 18:54:29   -7      1     222          9            22       8505
# 2020-11-05 18:55:31  -16      0     208          9            24       8727
# ...                  ...    ...     ...        ...           ...        ...
# 2020-11-06 19:09:41   66      0     226          9            34       8679
# 2020-11-06 19:11:09    6      0      14          8            62       9309
# 2020-11-06 19:12:29   22      0       6          9            22       9915
# 2020-11-06 19:13:33   33      0     231          8            26       9985
# 2020-11-06 19:14:25   36      0      20          8            18      10096
#
#                      vAccuracy             DateTime  CalcVoltage    CalcLat  \
# datetime
# 2020-11-05 18:51:45      22468  2020-11-05 18:51:45     3.723529  51.386936
# 2020-11-05 18:52:20      21032  2020-11-05 18:52:20     3.723529  51.386773
# 2020-11-05 18:53:31      22833  2020-11-05 18:53:31     3.723529  51.386818
# 2020-11-05 18:54:29      23170  2020-11-05 18:54:29     3.723529  51.386859
# 2020-11-05 18:55:31      23045  2020-11-05 18:55:31     3.723529  51.386856
# ...                        ...                  ...          ...        ...
# 2020-11-06 19:09:41      23075  2020-11-06 19:09:41     3.441176  51.386916
# 2020-11-06 19:11:09      23008  2020-11-06 19:11:09     3.441176  51.386938
# 2020-11-06 19:12:29      22700  2020-11-06 19:12:29     3.441176  51.386954
# 2020-11-06 19:13:33      22842  2020-11-06 19:13:33     3.441176  51.386930
# 2020-11-06 19:14:25      22643  2020-11-06 19:14:25     3.441176  51.386839
#
#                      CalcLong                   geometry
# datetime
# 2020-11-05 18:51:45 -0.408390  POINT (-0.40839 51.38694)
# 2020-11-05 18:52:20 -0.408353  POINT (-0.40835 51.38677)
# 2020-11-05 18:53:31 -0.408273  POINT (-0.40827 51.38682)
# 2020-11-05 18:54:29 -0.408194  POINT (-0.40819 51.38686)
# 2020-11-05 18:55:31 -0.408216  POINT (-0.40822 51.38686)
# ...                       ...                        ...
# 2020-11-06 19:09:41 -0.408276  POINT (-0.40828 51.38692)
# 2020-11-06 19:11:09 -0.408101  POINT (-0.40810 51.38694)
# 2020-11-06 19:12:29 -0.408118  POINT (-0.40812 51.38695)
# 2020-11-06 19:13:33 -0.408133  POINT (-0.40813 51.38693)
# 2020-11-06 19:14:25 -0.408135  POINT (-0.40813 51.38684)
#
# [1348 rows x 17 columns]

# %%
m = folium.Map(location=[51.3868702, -0.4080927], zoom_start=16)

polygon = gpd.read_file('geofence.json')
for index, row in polygon.iterrows():
    pip_mask_geofence = gdf['geometry'].within(row['geometry'])
    gdf.loc[:,'within'] |= pip_mask_geofence

for index, row in gdf.iterrows(): 
    if (math.isnan(row["CalcLong"]) == False and math.isnan(row["CalcLat"]) == False):
        popupmsg  = "<div style='width: 200px'><b>"+str(row["DateTime"]) + "</b><br />"
        popupmsg += "Altitude: "+str(row["Alt"]) + "<br />"
        popupmsg += "Seconds to fix: "+str(row["SecondsToFix"]) + "<br />"
        popupmsg += "Satelites: "+str(row["Satelites"]) + "<br />"
        popupmsg += "Course: "+str(row["Course"]) + "<br />"
        popupmsg += "Speed: "+str(row["Speed"]) + "<br />"
        popupmsg += "h-Accuracy: "+str(row["hAccuracy"]) + "<br />"
        popupmsg += "v-Accuracy: "+str(row["vAccuracy"]) + "<br />"
        popupmsg += "</div>"
        pop = folium.map.Popup(html=popupmsg, max_width="200px", parse_html= False)
 
        
        if (row["within"] == False):
            folium.Circle(radius=1, location=[row["CalcLat"], row["CalcLong"]], popup=pop, fill=True, color="red").add_to(m)
        else:
            folium.Circle(radius=1, location=[row["CalcLat"], row["CalcLong"]], popup=pop, fill=True, color="blue").add_to(m)
# m.save("loramap.html")

folium.GeoJson("geofence.json").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
